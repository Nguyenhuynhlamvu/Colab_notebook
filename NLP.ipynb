# %%
# !pip install youtube-search

# %%
from youtube_search import YoutubeSearch
import matplotlib.pyplot as plt
# import webbrowser

# %%
a=[]
mysong=input("ten bai hat: ")
print(mysong)
result = YoutubeSearch(mysong, max_results=10).to_dict()
print(result)
for i in range (10):
  # result[i]['views'][0:-]
  a.append(result[i]['views'][0:-6])
url="http://www.youtube.com" +result[0]["url_suffix"]
print(url)
print(a)
# plt.plot(a)
# plt.show()
# webbrowser.open(url)

# %%
# !pip install SpeechRecognition
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url="/content/drive/MyDrive/Cnn/HappyForYou.wav"

# %%
import speech_recognition as sr 
filename="HappyForYou.wav"
url="/content/drive/MyDrive/Cnn/La.wav"
r=sr.Recognizer()
with sr.AudioFile(url) as source:
  audio_data=r.record(source,offset=2,duration=30)
text=r.recognize_google(audio_data, language="vi-VI",show_all = True)
print(text)
# Out:
# {'alternative': [{'transcript': 'kiếm ăn đêm Mang Tên Em Quay Về trong thời gian', 'confidence': 0.87340987}, {'transcript': 'kiếm ăn đêm không mang tên em quay về trong thời gian'}, {'transcript': 'kiếm ăn đêm khi mang tên em quay về trong thời gian'}, {'transcript': 'điểm ăn đêm Mang Tên Em Quay Về trong thời gian'}, {'transcript': 'kiếm ăn đêm Mang Tên Em Quay Về trong ký ức thời gian'}], 'final': True}

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install playsound
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from playsound import playsound
import speech_recognition as sr
from gtts import gTTS
import os
text="Báo quá Báo"
speak=gTTS(ab, lang='vi',slow='false')
speak.save("test.mp3")
# playsound("test.mp3")
# os.remove('test.mp3')
print(text)
# Out:
# WARNING:playsound:playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.
# Báo quá Báo

# %%
os.remove('test.mp3')
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
# !pip install googletrans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 37.8 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.7 MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=4ab7fb0e281e48adbdc39a6ae4447f49b7265a34b20e5be7f5c4360cbe9b7a4e
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# ...

# %%
from googletrans import Translator
dich=Translator()
a="Kìa màn đêm hiu hắt mang tên em,Quay về trong ký ức của anh qua thời gian,Chiều lặng im nghe gió đung đưa cây"
trans=dich.translate(text,src='vi',dcst='en')
ab=trans.text
print(trans.text)
# Out:
# {'alternative': [{'transcript': 'foraging for the night Bringing Your Name Back in Time', 'confidence': 0.87340987}, {'transcript': 'foraging the night without your name returning in time' '}, {'transcript': 'foraging in the night while bringing your name back in time'}, {'transcript': 'eating at night bringing your name back in time'}, {'transcript': ' Nocturnal feeding Bringing Your Name Back in Time's Memory'}], 'final': True}

# %%
# !pip uninstall googletrans
# !pip install googletrans==3.1.0a0
# Out:
# Found existing installation: googletrans 3.0.0
# Uninstalling googletrans-3.0.0:
#   Would remove:
#     /usr/local/bin/translate
#     /usr/local/lib/python3.7/dist-packages/googletrans-3.0.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/googletrans/*
# Proceed (y/n)? y
#   Successfully uninstalled googletrans-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16368 sha256=6f3f3c31b29661d540124688f78447b612481b0470ec0e97bdeda794d872d5e3
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# ...
